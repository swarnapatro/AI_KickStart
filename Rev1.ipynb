# %% [markdown]
# <a href="https://colab.research.google.com/github/swarnapatro/AI_KickStart/blob/main/Rev1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#list, tuple,range
x = ["apple", "banana", "cherry"]

# %%
x
# Out:
# ['apple', 'banana', 'cherry']

# %%
y = {"name" : "John", "age" : 36}
y
# Out:
# {'name': 'John', 'age': 36}

# %%
#scatter plot The x array represents the age of each car. The y array represents the speed of each car.

import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]

y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)

plt.show()

# %%
#Linear Regression
from scipy import stats
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
slope, intercept, r, p, std_err = stats.linregress(x, y)
print("The equation of the line is y = {}x + {}".format(slope, intercept))

def myfunction(x):
  return slope * x + intercept

  model = list(map(myfunction, x))

  plt.scatter(x, y)
  plt.plot(x, model)
  plt.show()
# Out:
# The equation of the line is y = -1.7512877115526118x + 103.10596026490066

# %%
#numpy array
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print(arr)

print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>
