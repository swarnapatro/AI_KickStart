# %% [markdown]
# <a href="https://colab.research.google.com/github/swarnapatro/AI_KickStart/blob/main/hello1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hi")
name = "swarna"
age = 43
percntage = 23.45
passed=True

type(percntage)
type(name)
type(age)
type(passed)
# Out:
# hi
# bool

# %%
type(age)
print (type(passed))
# Out:
# <class 'bool'>

# %%
marks=[33,64,53,90]
student= {"name": "hari","age":43}
subjects={"Python","sql","java"}

# %%
python=67
sql=78
java=101

# %%
print(percntage)
if percntage>=10:
  print("hi")
elif percntage >= 21 and percntage<22:
  print("gone")

# %%
print (total)
python%2
percntage >23

print(percntage)
if percntage>=10:
  print("hdddi")
elif percntage >= 21 and percntage<24:
  print("gonedff")
# Out:
# 246
# 23.45
# hdddi

# %%
name="swarna"
college = "driems cuttack "

name[0]
college[0]
len(college)
# Out:
# 15

# %%
college.strip()
# Out:
# 'driems cuttack'

# %%
college.upper()
# Out:
# 'DRIEMS CUTTACK '

# %%
college.lower()
# Out:
# 'driems cuttack '

# %%
college.title()
# Out:
# 'Driems Cuttack '

# %%
college.startswith("d")
# Out:
# True

# %%
marks = [23, 56, 78, 65, 11, 33, 67]

# %%
marks[3]
# Out:
# 65

# %%
marks[0:2]
# Out:
# [23, 56]

# %%
marks.append(99)

# %%
print(marks)
# Out:
# [23, 56, 78, 65, 11, 33, 67, 99, 99]

# %%
marks.insert(2,77)

# %%
print(marks)
# Out:
# [23, 56, 77, 78, 65, 11, 33, 67, 99, 99]

# %%
marks.remove(56)

# %%
marks
# Out:
# [23, 77, 78, 65, 11, 33, 67, 99, 99]

# %%
marks.pop()
# Out:
# 99

# %%
marks
# Out:
# [23, 77, 78, 65, 11, 33, 67, 99]

# %%
marks.insert(4,55)

# %%
#tupples
college_location= (19.342, 45.43)

# %%
college_location[0]
# Out:
# 19.342

# %%
user_profile={"name": "swarna", "age": 33, "pass": True}

# %%
user_profile
# Out:
# {'name': 'swarna', 'age': 33, 'pass': True}

# %%
user_profile["age"]
# Out:
# 33

# %%
user_profile["sub"]="math"

# %%
user_profile
# Out:
# {'name': 'swarna', 'age': 33, 'pass': True, 'sub': 'math'}

# %%
del user_profile["pass"]

# %%
user_profile
# Out:
# {'name': 'swarna', 'age': 33, 'sub': 'math'}

# %%
user_profile.keys()
# Out:
# dict_keys(['name', 'age', 'sub'])

# %%
user_profile = {"name": "swarna", "age": 33, "sub": "math", "marks" :[23, 56, 78, 65, 11, 33, 67]}

# %%
user_profile
# Out:
# {'name': 'swarna',
#  'age': 33,
#  'sub': 'math',
#  'marks': [23, 56, 78, 65, 11, 33, 67]}
