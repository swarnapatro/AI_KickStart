# %% [markdown]
# <a href="https://colab.research.google.com/github/swarnapatro/AI_KickStart/blob/main/Modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a,b):
  print (a+b)
  return a+b

# %%
def sub(a,b):
   result = a-b
   return result

# %%
def mul (a,b):
  result = a*b
  return result

# %%
def division(a,b):
    result = a/b
    return result

# %%
print(add(2,3))
print(sub(2,3))
print(mul(2,3))
print(division(2,3))
# Out:
# 5
# 5
# -1
# 6
# 0.6666666666666666

# %%
# %%writefile calculation.py

def add(a,b):
  print (a+b)
  return a+b

def sub(a,b):
   result = a-b
   return result

def mul (a,b):
  result = a*b
  return result

def division(a,b):
    result = a/b
    return result
# Out:
# Writing calculation.py

# %%
# !ls
# Out:
# calculation.py	sample_data
