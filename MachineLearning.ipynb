# %% [markdown]
# <a href="https://colab.research.google.com/github/swarnapatro/AI_KickStart/blob/main/MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#simple regression
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


data = {"Exp": [1,2,3,4,5,6], "Salary": [35,40,48,55,62,72]}
df= pd.DataFrame(data)
print(df)
# Out:
#    Exp  Salary
# 0    1      35
# 1    2      40
# 2    3      48
# 3    4      55
# 4    5      62
# 5    6      72

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.title("Experience vs Salary")

plt.scatter(df["Exp"],df["Salary"])

plt.show()

# %%
advdata = {"Advertisement":[11000,22000,31000,41000],"Sale":[24000,34000,44000,56000]}
df1= pd.DataFrame(advdata)
print(df1)


plt.xlabel("Advertisement")
plt.ylabel("Sale")
plt.title("Advertisement vs Sale")

plt.scatter(df1["Advertisement"],df1["Sale"])

plt.show()
# Out:
#    Advertisement   Sale
# 0          11000  24000
# 1          22000  34000
# 2          31000  44000
# 3          41000  56000

# %%
prediction=75
actual=71
residual= actual-prediction
print(residual)
# Out:
# -4

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X= df[["Exp"]] # Reshape X to be a 2D DataFrame
y= df["Salary"]

model=LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[9]])
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([92.54285714])

# %%
model.coef_[0]
# Out:
# np.float64(7.371428571428572)

# %%
model.predict([[12]])
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([114.65714286])

# %%
aa=model.predict([[30],[40],[50],[60],[70],[80]])
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
prediction=model.predict(X)
plt.scatter(X,prediction,color="red")
plt.plot(X,prediction,color="red")
plt.show()

# %%
prediction=model.predict(X)
plt.scatter(X,aa,color="blue")
plt.plot(X,aa,color="red")
plt.show()
