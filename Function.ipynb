# %% [markdown]
# <a href="https://colab.research.google.com/github/swarnapatro/AI_KickStart/blob/main/Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
b=6
c=a+b
print(c)

# %%
#basic program for food delivery app > calculate food subtotal, calculate GST
