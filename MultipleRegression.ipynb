# %% [markdown]
# <a href="https://colab.research.google.com/github/swarnapatro/AI_KickStart/blob/main/MultipleRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {
    "Exp" : [1,2,3,5,7,10,12] ,
    "Edu" :  [12,14,14,16,18,18,20] ,
    "Salary" : [10000,20000,30000,40000,50000,52000,55000]
}


df= pd.DataFrame(data)
print(df)
# Out:
#    Exp  Edu  Salary
# 0    1   12   10000
# 1    2   14   20000
# 2    3   14   30000
# 3    5   16   40000
# 4    7   18   50000
# 5   10   18   52000
# 6   12   20   55000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df)
plt.show()

# %%
X=df[["Exp","Edu"]]
y= df["Salary"]

# %%
from os import XATTR_CREATE
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test= train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#    Exp  Edu
# 6   12   20
# 0    1   12
# 3    5   16
# 4    7   18
# 2    3   14

# %%
y_train
# Out:
# 6    55000
# 0    10000
# 3    40000
# 4    50000
# 2    30000
# Name: Salary, dtype: int64

# %%
X_test
# Out:
#    Exp  Edu
# 1    2   14
# 5   10   18

# %%
y_test
# Out:
# 1    20000
# 5    52000
# Name: Salary, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()
