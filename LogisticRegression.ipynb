# %% [markdown]
# <a href="https://colab.research.google.com/github/swarnapatro/AI_KickStart/blob/main/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
#studying less than 3 hrs chances are to fail.
X = np.array([[1],[2],[3],[4],[5]])
y= np.array([[0,0,0,1,1]])

# %%
model=LogisticRegression()

# %%
def prediction_pass(hours):
  prediction = model.predict([[hours]])
  if prediction[0]==1:
     print("pass")
  else:
     print("fail")

# %%
prediction_pass(5)
# Out:
# pass

# %%
b= model.predict(X_test)

# %%
b
# Out:
# array([0, 0, 1, 1, 1])

# %%
b[0]
# Out:
# np.int64(0)
